# %% [markdown]
# <a href="https://colab.research.google.com/github/ytl0623/yolov8-fire-car-and-smoke-detection/blob/master/Deep_Learning_Based_Fire_Vehicle_Detection_and_Real_Time_Warning_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Clone Repository

# %%
# !git clone https://github.com/ytl0623/yolov8-fire-car-and-smoke-detection.git

# %% [markdown]
# Go to the cloned folder

# %%
cd yolov8-fire-car-and-smoke-detection

# %% [markdown]
# Install the dependencies

# %%
# !pip install -r requirements.txt

# %% [markdown]
# Go to the working directory

# %%
cd ultralytics/yolo/v8/detect/

# %% [markdown]
# Modify E-mail address
#
# Change your desire email address in ```send_email.py```.

# %%
your_email =
your_password =
send_email_to =

# %% [markdown]
# Execute inference
#
# Change the input of the image/video/rtsp/..., what ever you want.

# %%
python main.py

# %% [markdown]
# Results
#
# The output image is like the below.
# ![螢幕擷取畫面 2023-08-15 173508.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# If the model detected the fire and smoke, the command line shows output ```Warning Fire!!! Send Email!``` and it will send email to desire person with the image contains bounding box.![螢幕擷取畫面 2023-08-15 174042.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Reference
# - https://github.com/ultralytics/ultralytics
# - https://github.com/gaiasd/DFireDataset
# - https://github.com/open-mmlab/mmyolo
